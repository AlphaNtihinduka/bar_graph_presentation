# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

dataset = pd.read_csv("vehicle.csv")
dataset
# Out:
#                       vehicleClass  2020  2019  2018  2017  2016  2015   2014  \
# 0                       Motor cars  5167  5972  5690  6255  6825  9526  10107
# 1            Dual-purpose vehicles   714   674   803   936  1013  1154   1077
# 2                    Light Omnibus  1289  2100  2241  2382  2607  3942   3833
# 3                   Medium Omnibus   141   189   217   182   225   305    255
# 4                    Heavy Omnibus   177   221   245   281   342   331    384
# 5             Light goods vehicles  1412  1359  1307  1323  1470  1580   1619
# 6            Medium goods vehicles   972   912   947   960  1075  1351   1259
# 7             Heavy goods vehicles   508   505   224   395   481   594    606
# 8       Trailers and Semi-Trailers   607   494   610   472   485   626    686
# 9                       Fuel Truck    92   123    90    93   150   151    124
# 10               Engineering plant    31    28    49    33    47    87     36
# 11                        Tractors    49    58    89    62    93    70     69
# 12                    Motor cycles  6305  5889  5503  6310  6537  8091   8038
# 13                    Pedal cycles   479   394   462   511   615   841   1051
# 14  Pedestrian Controlled Vehicles    49    60    49    36    20    44     30
#
#      2013   2012   2011  Unnamed: 11  Unnamed: 12
# 0   10058  11386  12095          NaN          NaN
# 1    1074   1161   2107          NaN          NaN
# 2    3259   3591   4480          NaN          NaN
# 3     296    402    318          NaN          NaN
# 4     392    465    664          NaN          NaN
# 5    1598   1809   2262          NaN          NaN
# 6    1014   1187   1468          NaN          NaN
# 7     500    456    608          NaN          NaN
# 8     606    510    752          NaN          NaN
# 9     224    327    149          NaN          NaN
# 10     57     58    115          NaN          NaN
# 11    127    111    209          NaN          NaN
# 12   7450   8073   8743          NaN          NaN
# 13    953   1140   1561          NaN          NaN
# 14     40     29    185          NaN          NaN

# %%
dataset.drop(columns=["Unnamed: 11", "Unnamed: 12"], inplace=True, axis=1)
dataset
# Out:
#                       vehicleClass  2020  2019  2018  2017  2016  2015   2014  \
# 0                       Motor cars  5167  5972  5690  6255  6825  9526  10107
# 1            Dual-purpose vehicles   714   674   803   936  1013  1154   1077
# 2                    Light Omnibus  1289  2100  2241  2382  2607  3942   3833
# 3                   Medium Omnibus   141   189   217   182   225   305    255
# 4                    Heavy Omnibus   177   221   245   281   342   331    384
# 5             Light goods vehicles  1412  1359  1307  1323  1470  1580   1619
# 6            Medium goods vehicles   972   912   947   960  1075  1351   1259
# 7             Heavy goods vehicles   508   505   224   395   481   594    606
# 8       Trailers and Semi-Trailers   607   494   610   472   485   626    686
# 9                       Fuel Truck    92   123    90    93   150   151    124
# 10               Engineering plant    31    28    49    33    47    87     36
# 11                        Tractors    49    58    89    62    93    70     69
# 12                    Motor cycles  6305  5889  5503  6310  6537  8091   8038
# 13                    Pedal cycles   479   394   462   511   615   841   1051
# 14  Pedestrian Controlled Vehicles    49    60    49    36    20    44     30
#
#      2013   2012   2011
# 0   10058  11386  12095
# 1    1074   1161   2107
# 2    3259   3591   4480
# 3     296    402    318
# 4     392    465    664
# 5    1598   1809   2262
# 6    1014   1187   1468
# 7     500    456    608
# 8     606    510    752
# 9     224    327    149
# 10     57     58    115
# 11    127    111    209
# 12   7450   8073   8743
# 13    953   1140   1561
# 14     40     29    185

# %%
dataset.set_index("vehicleClass", inplace=True)
dataset
# Out:
#                                 2020  2019  2018  2017  2016  2015   2014  \
# vehicleClass
# Motor cars                      5167  5972  5690  6255  6825  9526  10107
# Dual-purpose vehicles            714   674   803   936  1013  1154   1077
# Light Omnibus                   1289  2100  2241  2382  2607  3942   3833
# Medium Omnibus                   141   189   217   182   225   305    255
# Heavy Omnibus                    177   221   245   281   342   331    384
# Light goods vehicles            1412  1359  1307  1323  1470  1580   1619
# Medium goods vehicles            972   912   947   960  1075  1351   1259
# Heavy goods vehicles             508   505   224   395   481   594    606
# Trailers and Semi-Trailers       607   494   610   472   485   626    686
# Fuel Truck                        92   123    90    93   150   151    124
# Engineering plant                 31    28    49    33    47    87     36
# Tractors                          49    58    89    62    93    70     69
# Motor cycles                    6305  5889  5503  6310  6537  8091   8038
# Pedal cycles                     479   394   462   511   615   841   1051
# Pedestrian Controlled Vehicles    49    60    49    36    20    44     30
#
#                                  2013   2012   2011
# vehicleClass
# Motor cars                      10058  11386  12095
# Dual-purpose vehicles            1074   1161   2107
# Light Omnibus                    3259   3591   4480
# Medium Omnibus                    296    402    318
# Heavy Omnibus                     392    465    664
# Light goods vehicles             1598   1809   2262
# Medium goods vehicles            1014   1187   1468
# Heavy goods vehicles              500    456    608
# Trailers and Semi-Trailers        606    510    752
# Fuel Truck                        224    327    149
# Engineering plant                  57     58    115
# Tractors                          127    111    209
# Motor cycles                     7450   8073   8743
# Pedal cycles                      953   1140   1561
# Pedestrian Controlled Vehicles     40     29    185

# %%
dataset.columns
# Out:
# Index(['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012',
#        '2011'],
#       dtype='object')

# %%
dataset.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7c3d0_row0_col0, #T_7c3d0_row1_col1, #T_7c3d0_row2_col2, #T_7c3d0_row3_col3, #T_7c3d0_row4_col4, #T_7c3d0_row5_col5, #T_7c3d0_row6_col6, #T_7c3d0_row7_col7, #T_7c3d0_row8_col8, #T_7c3d0_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7c3d0_row0_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_7c3d0_row0_col2, #T_7c3d0_row0_col4, #T_7c3d0_row0_col5, #T_7c3d0_row0_col6, #T_7c3d0_row0_col7, #T_7c3d0_row0_col8, #T_7c3d0_row0_col9, #T_7c3d0_row8_col3, #T_7c3d0_row9_col0, #T_7c3d0_row9_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7c3d0_row0_col3, #T_7c3d0_row7_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_7c3d0_row1_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_7c3d0_row1_col2 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_7c3d0_row1_col3, #T_7c3d0_row2_col3, #T_7c3d0_row2_col4, #T_7c3d0_row3_col1, #T_7c3d0_row4_col2, #T_7c3d0_row8_col9, #T_7c3d0_row9_col8 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_7c3d0_row1_col4 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_7c3d0_row1_col5 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_7c3d0_row1_col6, #T_7c3d0_row3_col6 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_7c3d0_row1_col7 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_7c3d0_row1_col8 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_7c3d0_row1_col9, #T_7c3d0_row5_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_7c3d0_row2_col0, #T_7c3d0_row4_col0, #T_7c3d0_row5_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_7c3d0_row2_col1, #T_7c3d0_row9_col6 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_7c3d0_row2_col5, #T_7c3d0_row7_col5 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_7c3d0_row2_col6 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_7c3d0_row2_col7 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_7c3d0_row2_col8 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_7c3d0_row2_col9 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_7c3d0_row3_col0, #T_7c3d0_row4_col9 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_7c3d0_row3_col2 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_7c3d0_row3_col4, #T_7c3d0_row6_col5 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_7c3d0_row3_col5 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_7c3d0_row3_col7 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_7c3d0_row3_col8 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_7c3d0_row3_col9 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_7c3d0_row4_col1, #T_7c3d0_row6_col8, #T_7c3d0_row9_col7 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_7c3d0_row4_col3, #T_7c3d0_row5_col6 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_7c3d0_row4_col5, #T_7c3d0_row5_col7 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_7c3d0_row4_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_7c3d0_row4_col7 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_7c3d0_row4_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_7c3d0_row5_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_7c3d0_row5_col2 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_7c3d0_row5_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_7c3d0_row5_col8 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_7c3d0_row5_col9 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_7c3d0_row6_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_7c3d0_row6_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_7c3d0_row6_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_7c3d0_row6_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_7c3d0_row6_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_7c3d0_row6_col7 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_7c3d0_row6_col9 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_7c3d0_row7_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7c3d0_row7_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7c3d0_row7_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_7c3d0_row7_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_7c3d0_row7_col6 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_7c3d0_row7_col8, #T_7c3d0_row8_col7 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_7c3d0_row7_col9 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_7c3d0_row8_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_7c3d0_row8_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_7c3d0_row8_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_7c3d0_row8_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_7c3d0_row8_col5 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_7c3d0_row8_col6 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_7c3d0_row9_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_7c3d0_row9_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_7c3d0_row9_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_7c3d0_row9_col5 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c3d0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >2020</th>
#       <th class="col_heading level0 col1" >2019</th>
#       <th class="col_heading level0 col2" >2018</th>
#       <th class="col_heading level0 col3" >2017</th>
#       <th class="col_heading level0 col4" >2016</th>
#       <th class="col_heading level0 col5" >2015</th>
#       <th class="col_heading level0 col6" >2014</th>
#       <th class="col_heading level0 col7" >2013</th>
#       <th class="col_heading level0 col8" >2012</th>
#       <th class="col_heading level0 col9" >2011</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c3d0_level0_row0" class="row_heading level0 row0" >2020</th>
#       <td id="T_7c3d0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7c3d0_row0_col1" class="data row0 col1" >0.986905</td>
#       <td id="T_7c3d0_row0_col2" class="data row0 col2" >0.980991</td>
#       <td id="T_7c3d0_row0_col3" class="data row0 col3" >0.985428</td>
#       <td id="T_7c3d0_row0_col4" class="data row0 col4" >0.981121</td>
#       <td id="T_7c3d0_row0_col5" class="data row0 col5" >0.961804</td>
#       <td id="T_7c3d0_row0_col6" class="data row0 col6" >0.956480</td>
#       <td id="T_7c3d0_row0_col7" class="data row0 col7" >0.950887</td>
#       <td id="T_7c3d0_row0_col8" class="data row0 col8" >0.943815</td>
#       <td id="T_7c3d0_row0_col9" class="data row0 col9" >0.940590</td>
#     </tr>
#     <tr>
#       <th id="T_7c3d0_level0_row1" class="row_heading level0 row1" >2019</th>
#       <td id="T_7c3d0_row1_col0" class="data row1 col0" >0.986905</td>
#       <td id="T_7c3d0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7c3d0_row1_col2" class="data row1 col2" >0.998139</td>
#       <td id="T_7c3d0_row1_col3" class="data row1 col3" >0.998926</td>
#       <td id="T_7c3d0_row1_col4" class="data row1 col4" >0.998721</td>
#       <td id="T_7c3d0_row1_col5" class="data row1 col5" >0.992579</td>
#       <td id="T_7c3d0_row1_col6" class="data row1 col6" >0.989581</td>
#       <td id="T_7c3d0_row1_col7" class="data row1 col7" >0.985194</td>
#       <td id="T_7c3d0_row1_col8" class="data row1 col8" >0.980739</td>
#       <td id="T_7c3d0_row1_col9" class="data row1 col9" >0.978986</td>
#     </tr>
#     <tr>
#       <th id="T_7c3d0_level0_row2" class="row_heading level0 row2" >2018</th>
#       <td id="T_7c3d0_row2_col0" class="data row2 col0" >0.980991</td>
#       <td id="T_7c3d0_row2_col1" class="data row2 col1" >0.998139</td>
#       <td id="T_7c3d0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7c3d0_row2_col3" class="data row2 col3" >0.998893</td>
#       <td id="T_7c3d0_row2_col4" class="data row2 col4" >0.999024</td>
#       <td id="T_7c3d0_row2_col5" class="data row2 col5" >0.994946</td>
#       <td id="T_7c3d0_row2_col6" class="data row2 col6" >0.991715</td>
#       <td id="T_7c3d0_r

# %%
features strongly correlated to 2020 are:
2019
2017
2016
